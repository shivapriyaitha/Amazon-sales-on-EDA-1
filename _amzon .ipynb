# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load CSV
df = pd.read_csv("amazon.csv")

# %%
df.head()
# Out:
#    order_id product_category          brand     price  discount_percent  \
# 0     10001          Grocery           Sony  86092.06                 0
# 1     10002           Beauty  Amazon Basics  52276.96                42
# 2     10003            Books         Lenovo  19507.89                 8
# 3     10004          Grocery  Amazon Basics  89223.61                22
# 4     10005          Fashion           Puma   3298.95                42
#
#    discounted_price  quantity_sold  total_revenue  rating  review_count  ...  \
# 0          86092.06              5      430460.30     4.1          5995  ...
# 1          30320.64              5      151603.20     2.6         40950  ...
# 2          17947.26              9      161525.34     3.0         38270  ...
# 3          69594.42              8      556755.36     4.7         12920  ...
# 4           1913.39              4        7653.56     4.8         22144  ...
#
#   device_type product_condition  seller_type return_status delivery_rating  \
# 0      Mobile               New  Marketplace      Returned            Good
# 1      Mobile               New       Amazon      Returned            Good
# 2     Desktop           Renewed       Amazon  Not Returned         Average
# 3      Mobile               New  Marketplace  Not Returned            Poor
# 4     Desktop           Renewed       Amazon  Not Returned         Average
#
#     season promotion_type membership  gender delivery_days
# 0   Summer     Bank Offer  Non-Prime    Male             1
# 1   Spring         Coupon      Prime  Female             9
# 2  Monsoon  Festival Sale      Prime    Male             5
# 3   Spring   No Promotion  Non-Prime  Female             8
# 4   Summer     Bank Offer  Non-Prime  Female             7
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           1000 non-null   int64
#  1   product_category   1000 non-null   object
#  2   brand              1000 non-null   object
#  3   price              1000 non-null   float64
#  4   discount_percent   1000 non-null   int64
#  5   discounted_price   1000 non-null   float64
#  6   quantity_sold      1000 non-null   int64
#  7   total_revenue      1000 non-null   float64
#  8   rating             1000 non-null   float64
#  9   review_count       1000 non-null   int64
#  10  customer_region    1000 non-null   object
#  11  customer_city      1000 non-null   object
#  12  payment_method     1000 non-null   object
#  13  order_status       1000 non-null   object
#  14  shipping_method    1000 non-null   object
#  15  customer_segment   1000 non-null   object
#  16  sales_channel      1000 non-null   object
#  17  device_type        1000 non-null   object
#  18  product_condition  1000 non-null   object
#  19  seller_type        1000 non-null   object
#  20  return_status      1000 non-null   object
#  21  delivery_rating    1000 non-null   object
#  22  season             1000 non-null   object
#  23  promotion_type     1000 non-null   object
#  24  membership         1000 non-null   object
#  25  gender             1000 non-null   object
#  26  delivery_days      1000 non-null   int64
# dtypes: float64(4), int64(5), object(18)
# memory usage: 211.1+ KB

# %%
sns.histplot(
    data=df,
    x="product_category",
    y="total_revenue",
    bins=30
)
# Out:
# <Axes: xlabel='product_category', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="product_category",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='product_category', ylabel='total_revenue'>

# %%
import seaborn as sns

sns.boxplot(
    data=df,
    x="product_category",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='product_category', ylabel='total_revenue'>

# %%
import seaborn as sns

sns.catplot(
    data=df,
    x="product_category",
    y="total_revenue",
    kind="box",
    height=8,
    aspect=1.8
)

# %%
sns.boxplot(
    data=df,
    x="brand",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='brand', ylabel='total_revenue'>

# %%
import seaborn as sns

sns.catplot(
    data=df,
    x="brand",
    y="total_revenue",
    kind="box",
    height=8,
    aspect=1.8
)

# %%
sns.boxplot(
    data=df,
    x="customer_region",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='customer_region', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="customer_city",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='customer_city', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="payment_method",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='payment_method', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="order_status",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='order_status', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="shipping_method",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='shipping_method', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="customer_segment",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='customer_segment', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="sales_channel",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='sales_channel', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="device_type",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='device_type', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="product_condition",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='product_condition', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="seller_type",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='seller_type', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="return_status",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='return_status', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="season",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='season', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="promotion_type",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='promotion_type', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="membership",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='membership', ylabel='total_revenue'>

# %%
sns.boxplot(
    data=df,
    x="gender",
    y="total_revenue"
)
# Out:
# <Axes: xlabel='gender', ylabel='total_revenue'>
